# %%
# %%bash
# cd ~
# MINICONDA_INSTALLER_SCRIPT=Anaconda3-5.3.1-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/archive/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# conda update -n base conda
# conda create -n vilbert-mt python=3.6
# conda activate vilbert-mt
#
# conda install ipython
# conda install -y pytorch
# conda install -y torchvision

# %%
# %%bash
# cd /content/drive/MyDrive/Research_P
# pip install --yes ninja yacs cython matplotlib ipython pytorch torchvision
# cd GitRepo/vision/
# python setup.py install
# cd ../../
#
# cd GitRepo/cocoapi/PythonAPI/
# python setup.py build_ext install
# cd ../../../
#
# cd GitRepo/maskrcnn-benchmark/
# python setup.py build develop
# cd ../../
#
# pip install -v --disable-pip-version-check --no-cache-dir ./GitRepo/apex/
#
# make -C ./tool/

# %%
# %%bash
# cd /content/drive/MyDrive/Research_P
# pip install ninja yacs cython matplotlib ipython pytorch torchvision
# cd GitRepo/vision/
# python setup.py install
#
# cd ../../

# %%
# %%bash
# conda activate vilbert-mt
